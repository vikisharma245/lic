# %% [markdown]
# <a href="https://colab.research.google.com/github/vikisharma245/lic/blob/main/Copy_of_Arbitrage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Statistical Arbitrage for Sports Betting

# %% [markdown]
# Using: Live Sports Odds API
# Documentation Link: https://the-odds-api.com/

# %% [markdown]
# This program will look for statistical arbitrage opportunities in the upcoming eight games across all sports.

# %% [markdown]
# ### Importing Dependencies and Acquiring API Key

# %%
# !pip install XlsxWriter
# Out:
# Collecting XlsxWriter
#   Downloading XlsxWriter-3.1.9-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: XlsxWriter
# Successfully installed XlsxWriter-3.1.9

# %%
import requests
import xlsxwriter
import pandas as pd
import numpy as np
import openpyxl
from openpyxl import Workbook, load_workbook
from openpyxl.styles import Border, Side, Font, Alignment, PatternFill, numbers

API_KEY = 'e8b4d3d83413e23f91f6d0b4febe4f94'

# %% [markdown]
# ### Defining Constants and Making API Call
# - ``BET_SIZE`` is the monetary amount in USD that you are willing to make for each bet. For example, if you define ``BET_SIZE`` as 100, you are telling the program that you want to bet a total of 100 dollars USD for each arbitrage opportunity that the program finds

# %%
SPORT = 'upcoming' # use the sport_key from the /sports endpoint below, or use 'upcoming' to see the next 8 games across all sports

REGIONS = 'us' # uk | us | eu | au. Multiple can be specified if comma delimited

MARKETS = 'h2h' # h2h | spreads | totals. Multiple can be specified if comma delimited

ODDS_FORMAT = 'decimal' # decimal | american

DATE_FORMAT = 'iso' # iso | unix

BET_SIZE = 10

odds_response = requests.get(
    f'https://api.the-odds-api.com/v4/sports/{SPORT}/odds',
    params={
        'api_key': 'e8b4d3d83413e23f91f6d0b4febe4f94',
        'regions': REGIONS,
        'markets': MARKETS,
        'oddsFormat': ODDS_FORMAT,
        'dateFormat': DATE_FORMAT,
    }
).json()

# %%
# odds_response
print(odds_response)
# Out:
# [{'id': 'd54d3d86c3c1777dbbb4828f3d4a3b9c', 'sport_key': 'cricket_international_t20', 'sport_title': 'International Twenty20', 'commence_time': '2024-01-14T13:30:00Z', 'home_team': 'India', 'away_team': 'Afghanistan', 'bookmakers': [{'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2024-01-14T15:24:52Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:52Z', 'outcomes': [{'name': 'Afghanistan', 'price': 5.6}, {'name': 'India', 'price': 1.13}]}]}]}, {'id': '0db11d86a289af12e6973e15890a6fa7', 'sport_key': 'cricket_international_t20', 'sport_title': 'International Twenty20', 'commence_time': '2024-01-14T13:30:00Z', 'home_team': 'Sri Lanka', 'away_team': 'Zimbabwe', 'bookmakers': [{'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2024-01-14T15:24:52Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:52Z', 'outcomes': [{'name': 'Sri Lanka', 'price': 1.29}, {'name': 'Zimbabwe', 'price': 3.35}]}]}]}, {'id': 'f20ac9331600a467977d940ff2c8b3aa', 'sport_key': 'soccer_netherlands_eredivisie', 'sport_title': 'Dutch Eredivisie', 'commence_time': '2024-01-14T13:30:21Z', 'home_team': 'Go Ahead Eagles', 'away_team': 'Ajax', 'bookmakers': [{'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2024-01-14T15:20:17Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:20:17Z', 'outcomes': [{'name': 'Ajax', 'price': 1.1}, {'name': 'Go Ahead Eagles', 'price': 101.0}, {'name': 'Draw', 'price': 6.5}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2024-01-14T15:24:17Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:16Z', 'outcomes': [{'name': 'Ajax', 'price': 1.01}, {'name': 'Go Ahead Eagles', 'price': 161.0}, {'name': 'Draw', 'price': 18.0}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-01-14T15:25:09Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:09Z', 'outcomes': [{'name': 'Ajax', 'price': 1.06}, {'name': 'Go Ahead Eagles', 'price': 151.0}, {'name': 'Draw', 'price': 8.5}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2024-01-14T15:13:45Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:13:45Z', 'outcomes': [{'name': 'Ajax', 'price': 1.15}, {'name': 'Go Ahead Eagles', 'price': 26.0}, {'name': 'Draw', 'price': 5.25}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2024-01-14T15:25:09Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:09Z', 'outcomes': [{'name': 'Ajax', 'price': 1.0}, {'name': 'Go Ahead Eagles', 'price': 51.0}, {'name': 'Draw', 'price': 20.0}]}]}, {'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2024-01-14T15:25:09Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:09Z', 'outcomes': [{'name': 'Ajax', 'price': 1.01}, {'name': 'Go Ahead Eagles', 'price': 1001.0}, {'name': 'Draw', 'price': 19.0}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2024-01-14T15:25:09Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:09Z', 'outcomes': [{'name': 'Ajax', 'price': 1.2}, {'name': 'Go Ahead Eagles', 'price': 24.0}, {'name': 'Draw', 'price': 4.45}]}]}]}, {'id': 'ef65b10b97a420f21d6e0864f3856a41', 'sport_key': 'soccer_netherlands_eredivisie', 'sport_title': 'Dutch Eredivisie', 'commence_time': '2024-01-14T13:31:23Z', 'home_team': 'Vitesse Arnhem', 'away_team': 'FC Utrecht', 'bookmakers': [{'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2024-01-14T15:20:17Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:20:17Z', 'outcomes': [{'name': 'FC Utrecht', 'price': 8.0}, {'name': 'Vitesse Arnhem', 'price': 14.0}, {'name': 'Draw', 'price': 1.12}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2024-01-14T15:24:17Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:16Z', 'outcomes': [{'name': 'FC Utrecht', 'price': 16.0}, {'name': 'Vitesse Arnhem', 'price': 26.0}, {'name': 'Draw', 'price': 1.04}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-01-14T15:25:09Z', 'markets': [{'key': 'h2h', 'last_update ...

# %% [markdown]
# ### Event Class
# - Each ``Event`` object represents an indivudal sporting event
# - The ``data`` parameter contains all of the odds data that is received from the API call

# %%
BOOKMAKER_INDEX = 0
NAME_INDEX = 1
ODDS_INDEX = 2
FIRST = 0

class Event:
    def __init__(self, data):
        self.data = data
        self.sport_key = data['sport_key']
        self.id = data['id']

    def find_best_odds(self):
        # number of possible outcomes for a sporting event
        num_outcomes = len(self.data['bookmakers'][FIRST]['markets'][FIRST]['outcomes'])
        self.num_outcomes = num_outcomes

        # finding the best odds for each outcome in each event
        best_odds = [[None, None, float('-inf')] for _ in range(num_outcomes)]
        # [Bookmaker, Name, Price]

        bookmakers = event.data['bookmakers']
        for index, bookmaker in enumerate(bookmakers):

            # determing the odds offered by each bookmaker
            for outcome in range(num_outcomes):

                # determining if any of the bookmaker odds are better than the current best odds
                bookmaker_odds = float(bookmaker['markets'][FIRST]['outcomes'][outcome]['price'])
                current_best_odds = best_odds[outcome][ODDS_INDEX]

                if bookmaker_odds > current_best_odds:
                    best_odds[outcome][BOOKMAKER_INDEX] = bookmaker['title']
                    best_odds[outcome][NAME_INDEX] = bookmaker['markets'][FIRST]['outcomes'][outcome]['name']
                    best_odds[outcome][ODDS_INDEX] = bookmaker_odds

        self.best_odds = best_odds
        return best_odds

    def arbitrage(self):
        total_arbitrage_percentage = 0
        for odds in self.best_odds:
            total_arbitrage_percentage += (1.0 / odds[ODDS_INDEX])

        self.total_arbitrage_percentage = total_arbitrage_percentage
        self.expected_earnings = (BET_SIZE / total_arbitrage_percentage) - BET_SIZE

        # if the sum of the reciprocals of the odds is less than 1, there is opportunity for arbitrage
        if total_arbitrage_percentage < 1:
            return True
        return False

    # converts decimal/European best odds to American best odds
    def convert_decimal_to_american(self):
        best_odds = self.best_odds
        for odds in best_odds:
            decimal = odds[ODDS_INDEX]
            if decimal >= 2:
                american = (decimal - 1) * 100
            elif decimal < 2:
                american = -100 / (decimal - 1)
            odds[ODDS_INDEX] = round(american, 2)
        return best_odds

    def calculate_arbitrage_bets(self):
        bet_amounts = []
        for outcome in range(self.num_outcomes):
            individual_arbitrage_percentage = 1 / self.best_odds[outcome][ODDS_INDEX]
            bet_amount = (BET_SIZE * individual_arbitrage_percentage) / self.total_arbitrage_percentage
            bet_amounts.append(round(bet_amount, 2))

        self.bet_amounts = bet_amounts
        return bet_amounts

# %% [markdown]
# ### Parsing Events and Calculating Arbitrage Bets
# - `BET_SIZE` is the amount of money in USD that you would like to bet across the outcomes of an event.
# - This calculation will used unbiased arbitrage, where the profit is the same regardless of the outcome.

# %%
events = []
for data in odds_response:
    events.append(Event(data))
    print(data)
    print()

arbitrage_events = []
for event in events:
    best_odds = event.find_best_odds()
    if event.arbitrage():
        arbitrage_events.append(event)

for event in arbitrage_events:
    event.calculate_arbitrage_bets()
    event.convert_decimal_to_american()
# Out:
# {'id': 'd54d3d86c3c1777dbbb4828f3d4a3b9c', 'sport_key': 'cricket_international_t20', 'sport_title': 'International Twenty20', 'commence_time': '2024-01-14T13:30:00Z', 'home_team': 'India', 'away_team': 'Afghanistan', 'bookmakers': [{'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2024-01-14T15:24:52Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:52Z', 'outcomes': [{'name': 'Afghanistan', 'price': 5.6}, {'name': 'India', 'price': 1.13}]}]}]}
#
# {'id': '0db11d86a289af12e6973e15890a6fa7', 'sport_key': 'cricket_international_t20', 'sport_title': 'International Twenty20', 'commence_time': '2024-01-14T13:30:00Z', 'home_team': 'Sri Lanka', 'away_team': 'Zimbabwe', 'bookmakers': [{'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2024-01-14T15:24:52Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:52Z', 'outcomes': [{'name': 'Sri Lanka', 'price': 1.29}, {'name': 'Zimbabwe', 'price': 3.35}]}]}]}
#
# {'id': 'f20ac9331600a467977d940ff2c8b3aa', 'sport_key': 'soccer_netherlands_eredivisie', 'sport_title': 'Dutch Eredivisie', 'commence_time': '2024-01-14T13:30:21Z', 'home_team': 'Go Ahead Eagles', 'away_team': 'Ajax', 'bookmakers': [{'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2024-01-14T15:20:17Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:20:17Z', 'outcomes': [{'name': 'Ajax', 'price': 1.1}, {'name': 'Go Ahead Eagles', 'price': 101.0}, {'name': 'Draw', 'price': 6.5}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2024-01-14T15:24:17Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:16Z', 'outcomes': [{'name': 'Ajax', 'price': 1.01}, {'name': 'Go Ahead Eagles', 'price': 161.0}, {'name': 'Draw', 'price': 18.0}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-01-14T15:25:09Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:09Z', 'outcomes': [{'name': 'Ajax', 'price': 1.06}, {'name': 'Go Ahead Eagles', 'price': 151.0}, {'name': 'Draw', 'price': 8.5}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2024-01-14T15:13:45Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:13:45Z', 'outcomes': [{'name': 'Ajax', 'price': 1.15}, {'name': 'Go Ahead Eagles', 'price': 26.0}, {'name': 'Draw', 'price': 5.25}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2024-01-14T15:25:09Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:09Z', 'outcomes': [{'name': 'Ajax', 'price': 1.0}, {'name': 'Go Ahead Eagles', 'price': 51.0}, {'name': 'Draw', 'price': 20.0}]}]}, {'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2024-01-14T15:25:09Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:09Z', 'outcomes': [{'name': 'Ajax', 'price': 1.01}, {'name': 'Go Ahead Eagles', 'price': 1001.0}, {'name': 'Draw', 'price': 19.0}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2024-01-14T15:25:09Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:09Z', 'outcomes': [{'name': 'Ajax', 'price': 1.2}, {'name': 'Go Ahead Eagles', 'price': 24.0}, {'name': 'Draw', 'price': 4.45}]}]}]}
#
# {'id': 'ef65b10b97a420f21d6e0864f3856a41', 'sport_key': 'soccer_netherlands_eredivisie', 'sport_title': 'Dutch Eredivisie', 'commence_time': '2024-01-14T13:31:23Z', 'home_team': 'Vitesse Arnhem', 'away_team': 'FC Utrecht', 'bookmakers': [{'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2024-01-14T15:20:17Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:20:17Z', 'outcomes': [{'name': 'FC Utrecht', 'price': 8.0}, {'name': 'Vitesse Arnhem', 'price': 14.0}, {'name': 'Draw', 'price': 1.12}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2024-01-14T15:24:17Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:16Z', 'outcomes': [{'name': 'FC Utrecht', 'price': 16.0}, {'name': 'Vitesse Arnhem', 'price': 26.0}, {'name': 'Draw', 'price': 1.04}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-01-14T15:25:09Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:09Z', 'outcomes': [{'name': 'FC Utrecht', 'price': 8.5}, {'name': 'Vitesse Arnhem', 'price': 12.0}, {'name': 'Draw', 'price': 1.12}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2024-01-14T15:13:45Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:13:45Z', 'outcomes': [{'name': 'FC Utrecht', 'price': 4.0}, {'name': 'Vitesse Arnhem', 'price': 7.25}, {'name': 'Draw', 'price': 1.4}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2024-01-14T15:25:09Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:09Z', 'outcomes': [{'name': 'FC Utrecht', 'price': 20.0}, {'name': 'Vitesse Arnhem', 'price': 26.0}, {'name': 'Draw', 'price': 1.02}]}]}, {'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2024-01-14T15:25:09Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:09Z', 'outcomes': [{'name': 'FC Utrecht', 'price': 21.0}, {'name': 'Vitesse Arnhem', 'price': 29.0}, {'name': 'Draw', 'price': 1.02}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2024-01-14T15:25:09Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:09Z', 'outcomes': [{'name': 'FC Utrecht', 'price': 3.2}, {'name': 'Vitesse Arnhem', 'price': 5.25}, {'name': 'Draw', 'price': 1.6}]}]}]}
#
# {'id': 'bd8253cb881adf42fea77673d4799a1f', 'sport_key': 'soccer_france_ligue_one', 'sport_title': 'Ligue 1 - France', 'commence_time': '2024-01-14T13:59:59Z', 'home_team': 'Nantes', 'away_team': 'Clermont', 'bookmakers': [{'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2024-01-14T15:24:25Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:25Z', 'outcomes': [{'name': 'Clermont', 'price': 5.8}, {'name': 'Nantes', 'price': 2.7}, {'name': 'Draw', 'price': 1.91}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-01-14T15:25:13Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:13Z', 'outcomes': [{'name': 'Clermont', 'price': 5.3}, {'name': 'Nantes', 'price': 2.46}, {'name': 'Draw', 'price': 2.08}]}]}, {'key': 'williamhill_us', 'title': 'Caesars', 'last_update': '2024-01-14T15:25:13Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:13Z', 'outcomes': [{'name': 'Clermont', 'price': 5.5}, {'name': 'Nantes', 'price': 2.5}, {'name': 'Draw', 'price': 2.05}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2024-01-14T15:25:13Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:13Z', 'outcomes': [{'name': 'Clermont', 'price': 5.0}, {'name': 'Nantes', 'price': 2.75}, {'name': 'Draw', 'price': 2.0}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2024-01-14T15:22:48Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:22:48Z', 'outcomes': [{'name': 'Clermont', 'price': 5.5}, {'name': 'Nantes', 'price': 2.45}, {'name': 'Draw', 'price': 2.05}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2024-01-14T15:25:14Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:14Z', 'outcomes': [{'name': 'Clermont', 'price': 5.8}, {'name': 'Nantes', 'price': 2.6}, {'name': 'Draw', 'price': 1.94}]}]}, {'key': 'wynnbet', 'title': 'WynnBET', 'last_update': '2024-01-14T15:25:13Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:13Z', 'outcomes': [{'name': 'Clermont', 'price': 5.0}, {'name': 'Nantes', 'price': 2.75}, {'name': 'Draw', 'price': 2.0}]}]}, {'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2024-01-14T15:24:24Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:24Z', 'outcomes': [{'name': 'Clermont', 'price': 5.5}, {'name': 'Nantes', 'price': 2.45}, {'name': 'Draw', 'price': 2.0}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2024-01-14T15:25:13Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:13Z', 'outcomes': [{'name': 'Clermont', 'price': 4.0}, {'name': 'Nantes', 'price': 2.15}, {'name': 'Draw', 'price': 2.45}]}]}]}
#
# {'id': 'e48dc90b7dbc57e15bd0e5d61afd3e11', 'sport_key': 'soccer_italy_serie_a', 'sport_title': 'Serie A - Italy', 'commence_time': '2024-01-14T14:00:02Z', 'home_team': 'Cagliari', 'away_team': 'Bologna', 'bookmakers': [{'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2024-01-14T15:23:38Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:23:38Z', 'outcomes': [{'name': 'Bologna', 'price': 3.2}, {'name': 'Cagliari', 'price': 5.9}, {'name': 'Draw', 'price': 1.71}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-01-14T15:24:32Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:32Z', 'outcomes': [{'name': 'Bologna', 'price': 2.93}, {'name': 'Cagliari', 'price': 5.75}, {'name': 'Draw', 'price': 1.77}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2024-01-14T15:24:34Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:34Z', 'outcomes': [{'name': 'Bologna', 'price': 3.1}, {'name': 'Cagliari', 'price': 5.75}, {'name': 'Draw', 'price': 1.69}]}]}, {'key': 'williamhill_us', 'title': 'Caesars', 'last_update': '2024-01-14T15:23:38Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:23:38Z', 'outcomes': [{'name': 'Bologna', 'price': 3.1}, {'name': 'Cagliari', 'price': 6.0}, {'name': 'Draw', 'price': 1.71}]}]}, {'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2024-01-14T15:24:31Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:31Z', 'outcomes': [{'name': 'Bologna', 'price': 3.1}, {'name': 'Cagliari', 'price': 5.75}, {'name': 'Draw', 'price': 1.71}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2024-01-14T15:24:31Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:31Z', 'outcomes': [{'name': 'Bologna', 'price': 3.25}, {'name': 'Cagliari', 'price': 6.5}, {'name': 'Draw', 'price': 1.65}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2024-01-14T15:24:32Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:32Z', 'outcomes': [{'name': 'Bologna', 'price': 3.35}, {'name': 'Cagliari', 'price': 6.25}, {'name': 'Draw', 'price': 1.62}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2024-01-14T15:24:31Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:31Z', 'outcomes': [{'name': 'Bologna', 'price': 2.35}, {'name': 'Cagliari', 'price': 4.25}, {'name': 'Draw', 'price': 2.1}]}]}, {'key': 'wynnbet', 'title': 'WynnBET', 'last_update': '2024-01-14T15:24:31Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:31Z', 'outcomes': [{'name': 'Bologna', 'price': 3.14}, {'name': 'Cagliari', 'price': 6.5}, {'name': 'Draw', 'price': 1.73}]}]}]}
#
# {'id': '0d2a71d0a577e5a6293cee400b5b3c14', 'sport_key': 'soccer_epl', 'sport_title': 'EPL', 'commence_time': '2024-01-14T14:00:03Z', 'home_team': 'Everton', 'away_team': 'Aston Villa', 'bookmakers': [{'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2024-01-14T15:24:03Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:03Z', 'outcomes': [{'name': 'Aston Villa', 'price': 3.1}, {'name': 'Everton', 'price': 3.6}, {'name': 'Draw', 'price': 2.15}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-01-14T15:24:59Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:59Z', 'outcomes': [{'name': 'Aston Villa', 'price': 3.2}, {'name': 'Everton', 'price': 3.3}, {'name': 'Draw', 'price': 2.26}]}]}, {'key': 'williamhill_us', 'title': 'Caesars', 'last_update': '2024-01-14T15:24:02Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:02Z', 'outcomes': [{'name': 'Aston Villa', 'price': 3.3}, {'name': 'Everton', 'price': 3.3}, {'name': 'Draw', 'price': 2.2}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2024-01-14T15:24:59Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:59Z', 'outcomes': [{'name': 'Aston Villa', 'price': 3.25}, {'name': 'Everton', 'price': 3.4}, {'name': 'Draw', 'price': 2.2}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2024-01-14T15:25:00Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:00Z', 'outcomes': [{'name': 'Aston Villa', 'price': 3.2}, {'name': 'Everton', 'price': 3.4}, {'name': 'Draw', 'price': 2.17}]}]}, {'key': 'wynnbet', 'title': 'WynnBET', 'last_update': '2024-01-14T15:24:59Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:59Z', 'outcomes': [{'name': 'Aston Villa', 'price': 3.25}, {'name': 'Everton', 'price': 3.5}, {'name': 'Draw', 'price': 2.2}]}]}, {'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2024-01-14T15:24:58Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:58Z', 'outcomes': [{'name': 'Aston Villa', 'price': 3.2}, {'name': 'Everton', 'price': 3.5}, {'name': 'Draw', 'price': 2.1}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2024-01-14T15:24:59Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:59Z', 'outcomes': [{'name': 'Aston Villa', 'price': 2.7}, {'name': 'Everton', 'price': 2.8}, {'name': 'Draw', 'price': 2.65}]}]}]}
#
# {'id': 'bb5551a617e3382095db9eb94bd51274', 'sport_key': 'soccer_france_ligue_one', 'sport_title': 'Ligue 1 - France', 'commence_time': '2024-01-14T14:00:04Z', 'home_team': 'Metz', 'away_team': 'Toulouse', 'bookmakers': [{'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2024-01-14T15:24:25Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:25Z', 'outcomes': [{'name': 'Metz', 'price': 15.0}, {'name': 'Toulouse', 'price': 1.3}, {'name': 'Draw', 'price': 4.2}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-01-14T15:25:13Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:13Z', 'outcomes': [{'name': 'Metz', 'price': 12.0}, {'name': 'Toulouse', 'price': 1.36}, {'name': 'Draw', 'price': 3.95}]}]}, {'key': 'williamhill_us', 'title': 'Caesars', 'last_update': '2024-01-14T15:25:13Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:13Z', 'outcomes': [{'name': 'Metz', 'price': 13.0}, {'name': 'Toulouse', 'price': 1.38}, {'name': 'Draw', 'price': 3.8}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2024-01-14T15:25:13Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:13Z', 'outcomes': [{'name': 'Metz', 'price': 16.0}, {'name': 'Toulouse', 'price': 1.29}, {'name': 'Draw', 'price': 4.5}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2024-01-14T15:22:48Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:22:48Z', 'outcomes': [{'name': 'Metz', 'price': 13.0}, {'name': 'Toulouse', 'price': 1.33}, {'name': 'Draw', 'price': 3.9}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2024-01-14T15:25:14Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:14Z', 'outcomes': [{'name': 'Metz', 'price': 14.0}, {'name': 'Toulouse', 'price': 1.32}, {'name': 'Draw', 'price': 3.95}]}]}, {'key': 'wynnbet', 'title': 'WynnBET', 'last_update': '2024-01-14T15:25:13Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:13Z', 'outcomes': [{'name': 'Metz', 'price': 18.0}, {'name': 'Toulouse', 'price': 1.29}, {'name': 'Draw', 'price': 4.33}]}]}, {'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2024-01-14T15:24:24Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:24Z', 'outcomes': [{'name': 'Metz', 'price': 14.0}, {'name': 'Toulouse', 'price': 1.33}, {'name': 'Draw', 'price': 4.0}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2024-01-14T15:25:13Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:13Z', 'outcomes': [{'name': 'Metz', 'price': 6.75}, {'name': 'Toulouse', 'price': 1.4}, {'name': 'Draw', 'price': 3.7}]}]}]}
#
# {'id': '71de3865492cb0df69f2d8692530498e', 'sport_key': 'soccer_france_ligue_one', 'sport_title': 'Ligue 1 - France', 'commence_time': '2024-01-14T14:00:11Z', 'home_team': 'Brest', 'away_team': 'Montpellier', 'bookmakers': [{'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2024-01-14T15:24:25Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:25Z', 'outcomes': [{'name': 'Brest', 'price': 1.12}, {'name': 'Montpellier', 'price': 31.0}, {'name': 'Draw', 'price': 6.5}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-01-14T15:25:13Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:13Z', 'outcomes': [{'name': 'Brest', 'price': 1.17}, {'name': 'Montpellier', 'price': 24.0}, {'name': 'Draw', 'price': 5.6}]}]}, {'key': 'williamhill_us', 'title': 'Caesars', 'last_update': '2024-01-14T15:25:13Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:13Z', 'outcomes': [{'name': 'Brest', 'price': 1.18}, {'name': 'Montpellier', 'price': 26.0}, {'name': 'Draw', 'price': 5.5}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2024-01-14T15:25:13Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:13Z', 'outcomes': [{'name': 'Brest', 'price': 1.13}, {'name': 'Montpellier', 'price': 26.0}, {'name': 'Draw', 'price': 7.0}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2024-01-14T15:22:48Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:22:48Z', 'outcomes': [{'name': 'Brest', 'price': 1.17}, {'name': 'Montpellier', 'price': 26.0}, {'name': 'Draw', 'price': 5.75}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2024-01-14T15:25:14Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:14Z', 'outcomes': [{'name': 'Brest', 'price': 1.13}, {'name': 'Montpellier', 'price': 29.0}, {'name': 'Draw', 'price': 6.5}]}]}, {'key': 'wynnbet', 'title': 'WynnBET', 'last_update': '2024-01-14T15:25:13Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:13Z', 'outcomes': [{'name': 'Brest', 'price': 1.14}, {'name': 'Montpellier', 'price': 35.0}, {'name': 'Draw', 'price': 6.5}]}]}, {'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2024-01-14T15:24:24Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:24Z', 'outcomes': [{'name': 'Brest', 'price': 1.18}, {'name': 'Montpellier', 'price': 23.0}, {'name': 'Draw', 'price': 5.5}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2024-01-14T15:25:13Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:13Z', 'outcomes': [{'name': 'Brest', 'price': 1.18}, {'name': 'Montpellier', 'price': 20.0}, {'name': 'Draw', 'price': 5.4}]}]}]}
#
# {'id': '120c3942bd0bad9d5ccd1feba1e98f3a', 'sport_key': 'icehockey_sweden_allsvenskan', 'sport_title': 'HockeyAllsvenskan', 'commence_time': '2024-01-14T14:00:19Z', 'home_team': 'Mora IK', 'away_team': 'Västerviks IK', 'bookmakers': [{'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2024-01-14T15:24:48Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:48Z', 'outcomes': [{'name': 'Mora IK', 'price': 1.09}, {'name': 'Västerviks IK', 'price': 6.1}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-01-14T15:24:49Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:49Z', 'outcomes': [{'name': 'Mora IK', 'price': 1.1}, {'name': 'Västerviks IK', 'price': 6.5}]}]}]}
#
# {'id': '27733fe646d3ddf99ac1efdb8b0c63bb', 'sport_key': 'soccer_africa_cup_of_nations', 'sport_title': 'Africa Cup of Nations', 'commence_time': '2024-01-14T14:00:47Z', 'home_team': 'Nigeria', 'away_team': 'Equatorial Guinea', 'bookmakers': [{'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2024-01-14T15:23:53Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:23:53Z', 'outcomes': [{'name': 'Equatorial Guinea', 'price': 14.0}, {'name': 'Nigeria', 'price': 1.87}, {'name': 'Draw', 'price': 2.0}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2024-01-14T15:24:50Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:50Z', 'outcomes': [{'name': 'Equatorial Guinea', 'price': 7.0}, {'name': 'Nigeria', 'price': 1.6}, {'name': 'Draw', 'price': 2.35}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2024-01-14T15:24:50Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:50Z', 'outcomes': [{'name': 'Equatorial Guinea', 'price': 14.0}, {'name': 'Nigeria', 'price': 2.0}, {'name': 'Draw', 'price': 2.0}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2024-01-14T15:23:52Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:23:52Z', 'outcomes': [{'name': 'Equatorial Guinea', 'price': 11.0}, {'name': 'Nigeria', 'price': 2.0}, {'name': 'Draw', 'price': 2.0}]}]}, {'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2024-01-14T15:24:50Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:50Z', 'outcomes': [{'name': 'Equatorial Guinea', 'price': 15.0}, {'name': 'Nigeria', 'price': 1.95}, {'name': 'Draw', 'price': 2.0}]}]}, {'key': 'williamhill_us', 'title': 'Caesars', 'last_update': '2024-01-14T15:24:50Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:50Z', 'outcomes': [{'name': 'Equatorial Guinea', 'price': 15.0}, {'name': 'Nigeria', 'price': 1.99}, {'name': 'Draw', 'price': 2.03}]}]}, {'key': 'wynnbet', 'title': 'WynnBET', 'last_update': '2024-01-14T15:24:50Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:50Z', 'outcomes': [{'name': 'Equatorial Guinea', 'price': 16.0}, {'name': 'Nigeria', 'price': 2.0}, {'name': 'Draw', 'price': 2.0}]}]}]}
#
# {'id': 'ba46efc948a12700353f1089618b7090', 'sport_key': 'soccer_germany_bundesliga', 'sport_title': 'Bundesliga - Germany', 'commence_time': '2024-01-14T14:31:40Z', 'home_team': 'VfL Bochum', 'away_team': 'Werder Bremen', 'bookmakers': [{'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2024-01-14T15:24:06Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:06Z', 'outcomes': [{'name': 'VfL Bochum', 'price': 2.6}, {'name': 'Werder Bremen', 'price': 3.6}, {'name': 'Draw', 'price': 2.45}]}]}, {'key': 'williamhill_us', 'title': 'Caesars', 'last_update': '2024-01-14T15:24:05Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:05Z', 'outcomes': [{'name': 'VfL Bochum', 'price': 2.55}, {'name': 'Werder Bremen', 'price': 3.3}, {'name': 'Draw', 'price': 2.7}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2024-01-14T15:25:01Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:01Z', 'outcomes': [{'name': 'VfL Bochum', 'price': 2.75}, {'name': 'Werder Bremen', 'price': 3.4}, {'name': 'Draw', 'price': 2.5}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-01-14T15:25:01Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:01Z', 'outcomes': [{'name': 'VfL Bochum', 'price': 2.58}, {'name': 'Werder Bremen', 'price': 3.45}, {'name': 'Draw', 'price': 2.58}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2024-01-14T15:25:03Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:03Z', 'outcomes': [{'name': 'VfL Bochum', 'price': 2.6}, {'name': 'Werder Bremen', 'price': 3.25}, {'name': 'Draw', 'price': 2.45}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2024-01-14T15:25:02Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:02Z', 'outcomes': [{'name': 'VfL Bochum', 'price': 2.7}, {'name': 'Werder Bremen', 'price': 3.3}, {'name': 'Draw', 'price': 2.55}]}]}, {'key': 'wynnbet', 'title': 'WynnBET', 'last_update': '2024-01-14T15:25:02Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:02Z', 'outcomes': [{'name': 'VfL Bochum', 'price': 2.75}, {'name': 'Werder Bremen', 'price': 3.4}, {'name': 'Draw', 'price': 2.5}]}]}, {'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2024-01-14T15:25:01Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:01Z', 'outcomes': [{'name': 'VfL Bochum', 'price': 2.6}, {'name': 'Werder Bremen', 'price': 3.4}, {'name': 'Draw', 'price': 2.5}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2024-01-14T15:25:02Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:02Z', 'outcomes': [{'name': 'VfL Bochum', 'price': 2.5}, {'name': 'Werder Bremen', 'price': 3.2}, {'name': 'Draw', 'price': 2.55}]}]}]}
#
# {'id': 'd38877702536079fb1da510525906c10', 'sport_key': 'soccer_italy_serie_b', 'sport_title': 'Serie B - Italy', 'commence_time': '2024-01-14T15:15:00Z', 'home_team': 'Parma', 'away_team': 'Ascoli', 'bookmakers': [{'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2024-01-14T15:23:45Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:23:45Z', 'outcomes': [{'name': 'Ascoli', 'price': 6.0}, {'name': 'Parma', 'price': 1.62}, {'name': 'Draw', 'price': 3.4}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-01-14T15:24:42Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:42Z', 'outcomes': [{'name': 'Ascoli', 'price': 5.5}, {'name': 'Parma', 'price': 1.67}, {'name': 'Draw', 'price': 3.4}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2024-01-14T15:24:42Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:42Z', 'outcomes': [{'name': 'Ascoli', 'price': 6.0}, {'name': 'Parma', 'price': 1.65}, {'name': 'Draw', 'price': 3.4}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2024-01-14T15:24:43Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:43Z', 'outcomes': [{'name': 'Ascoli', 'price': 5.25}, {'name': 'Parma', 'price': 1.61}, {'name': 'Draw', 'price': 3.4}]}]}, {'key': 'betus', 'title': 'BetUS', 'last_update': '2024-01-14T15:15:48Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:15:48Z', 'outcomes': [{'name': 'Ascoli', 'price': 5.4}, {'name': 'Parma', 'price': 1.65}, {'name': 'Draw', 'price': 3.65}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2024-01-14T15:24:42Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:42Z', 'outcomes': [{'name': 'Ascoli', 'price': 5.1}, {'name': 'Parma', 'price': 1.63}, {'name': 'Draw', 'price': 3.35}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2024-01-14T15:13:16Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:13:16Z', 'outcomes': [{'name': 'Ascoli', 'price': 5.5}, {'name': 'Parma', 'price': 1.61}, {'name': 'Draw', 'price': 3.65}]}]}, {'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2024-01-14T15:14:48Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:14:48Z', 'outcomes': [{'name': 'Ascoli', 'price': 4.85}, {'name': 'Parma', 'price': 1.68}, {'name': 'Draw', 'price': 3.5}]}]}, {'key': 'lowvig', 'title': 'LowVig.ag', 'last_update': '2024-01-14T15:14:51Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:14:51Z', 'outcomes': [{'name': 'Ascoli', 'price': 4.85}, {'name': 'Parma', 'price': 1.68}, {'name': 'Draw', 'price': 3.5}]}]}]}
#
# {'id': '118b41762330e38efff6b5b3cb16d017', 'sport_key': 'soccer_italy_serie_b', 'sport_title': 'Serie B - Italy', 'commence_time': '2024-01-14T15:15:00Z', 'home_team': 'Cremonese', 'away_team': 'Cosenza', 'bookmakers': [{'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2024-01-14T15:23:45Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:23:45Z', 'outcomes': [{'name': 'Cosenza', 'price': 7.0}, {'name': 'Cremonese', 'price': 1.48}, {'name': 'Draw', 'price': 3.9}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-01-14T15:24:42Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:42Z', 'outcomes': [{'name': 'Cosenza', 'price': 6.0}, {'name': 'Cremonese', 'price': 1.54}, {'name': 'Draw', 'price': 3.8}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2024-01-14T15:24:42Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:42Z', 'outcomes': [{'name': 'Cosenza', 'price': 7.0}, {'name': 'Cremonese', 'price': 1.43}, {'name': 'Draw', 'price': 4.4}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2024-01-14T15:24:42Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:42Z', 'outcomes': [{'name': 'Cosenza', 'price': 6.25}, {'name': 'Cremonese', 'price': 1.42}, {'name': 'Draw', 'price': 3.95}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2024-01-14T15:24:43Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:43Z', 'outcomes': [{'name': 'Cosenza', 'price': 6.25}, {'name': 'Cremonese', 'price': 1.48}, {'name': 'Draw', 'price': 3.7}]}]}, {'key': 'betus', 'title': 'BetUS', 'last_update': '2024-01-14T15:15:48Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:15:48Z', 'outcomes': [{'name': 'Cosenza', 'price': 6.26}, {'name': 'Cremonese', 'price': 1.51}, {'name': 'Draw', 'price': 3.88}]}]}, {'key': 'lowvig', 'title': 'LowVig.ag', 'last_update': '2024-01-14T15:14:51Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:14:51Z', 'outcomes': [{'name': 'Cosenza', 'price': 6.1}, {'name': 'Cremonese', 'price': 1.51}, {'name': 'Draw', 'price': 3.95}]}]}, {'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2024-01-14T15:14:48Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:14:48Z', 'outcomes': [{'name': 'Cosenza', 'price': 6.1}, {'name': 'Cremonese', 'price': 1.51}, {'name': 'Draw', 'price': 3.95}]}]}]}
#
# {'id': '5c2360c1799572961f066f4f7b0699da', 'sport_key': 'soccer_spain_la_liga', 'sport_title': 'La Liga - Spain', 'commence_time': '2024-01-14T15:15:00Z', 'home_team': 'Cádiz CF', 'away_team': 'Valencia', 'bookmakers': [{'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2024-01-14T15:24:29Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:29Z', 'outcomes': [{'name': 'Cádiz CF', 'price': 7.0}, {'name': 'Valencia', 'price': 1.48}, {'name': 'Draw', 'price': 4.0}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-01-14T15:25:18Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:18Z', 'outcomes': [{'name': 'Cádiz CF', 'price': 2.95}, {'name': 'Valencia', 'price': 2.72}, {'name': 'Draw', 'price': 2.78}]}]}, {'key': 'williamhill_us', 'title': 'Caesars', 'last_update': '2024-01-14T15:23:35Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:23:35Z', 'outcomes': [{'name': 'Cádiz CF', 'price': 3.1}, {'name': 'Valencia', 'price': 2.65}, {'name': 'Draw', 'price': 2.75}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2024-01-14T15:24:29Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:29Z', 'outcomes': [{'name': 'Cádiz CF', 'price': 9.5}, {'name': 'Valencia', 'price': 1.37}, {'name': 'Draw', 'price': 4.3}]}]}, {'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2024-01-14T15:24:28Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:28Z', 'outcomes': [{'name': 'Cádiz CF', 'price': 7.0}, {'name': 'Valencia', 'price': 1.44}, {'name': 'Draw', 'price': 4.0}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2024-01-14T15:25:18Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:18Z', 'outcomes': [{'name': 'Cádiz CF', 'price': 7.0}, {'name': 'Valencia', 'price': 1.49}, {'name': 'Draw', 'price': 3.75}]}]}, {'key': 'betus', 'title': 'BetUS', 'last_update': '2024-01-14T15:14:41Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:14:41Z', 'outcomes': [{'name': 'Cádiz CF', 'price': 3.08}, {'name': 'Valencia', 'price': 2.65}, {'name': 'Draw', 'price': 2.85}]}]}, {'key': 'lowvig', 'title': 'LowVig.ag', 'last_update': '2024-01-14T15:14:44Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:14:44Z', 'outcomes': [{'name': 'Cádiz CF', 'price': 3.13}, {'name': 'Valencia', 'price': 2.72}, {'name': 'Draw', 'price': 2.88}]}]}, {'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2024-01-14T15:15:32Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:15:32Z', 'outcomes': [{'name': 'Cádiz CF', 'price': 3.13}, {'name': 'Valencia', 'price': 2.72}, {'name': 'Draw', 'price': 2.88}]}]}, {'key': 'superbook', 'title': 'SuperBook', 'last_update': '2024-01-14T15:11:51Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:11:51Z', 'outcomes': [{'name': 'Cádiz CF', 'price': 3.05}, {'name': 'Valencia', 'price': 2.65}, {'name': 'Draw', 'price': 2.8}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2024-01-14T15:25:18Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:18Z', 'outcomes': [{'name': 'Cádiz CF', 'price': 3.1}, {'name': 'Valencia', 'price': 2.65}, {'name': 'Draw', 'price': 2.85}]}]}, {'key': 'wynnbet', 'title': 'WynnBET', 'last_update': '2024-01-14T15:25:18Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:18Z', 'outcomes': [{'name': 'Cádiz CF', 'price': 7.0}, {'name': 'Valencia', 'price': 1.53}, {'name': 'Draw', 'price': 3.8}]}]}]}
#
# {'id': 'c01a4094ca8f66e785d74c99a6c892ec', 'sport_key': 'soccer_spain_segunda_division', 'sport_title': 'La Liga 2 - Spain', 'commence_time': '2024-01-14T15:15:00Z', 'home_team': 'FC Cartagena', 'away_team': 'Villarreal', 'bookmakers': [{'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2024-01-14T15:21:56Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:21:56Z', 'outcomes': [{'name': 'FC Cartagena', 'price': 2.3}, {'name': 'Villarreal', 'price': 3.1}, {'name': 'Draw', 'price': 2.9}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-01-14T15:24:46Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:46Z', 'outcomes': [{'name': 'FC Cartagena', 'price': 2.42}, {'name': 'Villarreal', 'price': 3.0}, {'name': 'Draw', 'price': 3.05}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2024-01-14T15:23:49Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:23:49Z', 'outcomes': [{'name': 'FC Cartagena', 'price': 2.3}, {'name': 'Villarreal', 'price': 3.1}, {'name': 'Draw', 'price': 2.8}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2024-01-14T15:23:01Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:23:01Z', 'outcomes': [{'name': 'FC Cartagena', 'price': 2.35}, {'name': 'Villarreal', 'price': 3.25}, {'name': 'Draw', 'price': 3.0}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2024-01-14T15:24:45Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:45Z', 'outcomes': [{'name': 'FC Cartagena', 'price': 2.5}, {'name': 'Villarreal', 'price': 2.85}, {'name': 'Draw', 'price': 2.95}]}]}, {'key': 'betus', 'title': 'BetUS', 'last_update': '2024-01-14T15:14:51Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:14:51Z', 'outcomes': [{'name': 'FC Cartagena', 'price': 2.35}, {'name': 'Villarreal', 'price': 3.1}, {'name': 'Draw', 'price': 3.15}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2024-01-14T15:23:46Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:23:46Z', 'outcomes': [{'name': 'FC Cartagena', 'price': 2.35}, {'name': 'Villarreal', 'price': 3.15}, {'name': 'Draw', 'price': 3.15}]}]}, {'key': 'lowvig', 'title': 'LowVig.ag', 'last_update': '2024-01-14T15:14:53Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:14:53Z', 'outcomes': [{'name': 'FC Cartagena', 'price': 2.42}, {'name': 'Villarreal', 'price': 2.93}, {'name': 'Draw', 'price': 3.05}]}]}, {'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2024-01-14T15:15:52Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:15:52Z', 'outcomes': [{'name': 'FC Cartagena', 'price': 2.42}, {'name': 'Villarreal', 'price': 2.93}, {'name': 'Draw', 'price': 3.05}]}]}]}
#
# {'id': 'c435d32a283a58cff7b842ac6d007ae9', 'sport_key': 'soccer_spain_segunda_division', 'sport_title': 'La Liga 2 - Spain', 'commence_time': '2024-01-14T15:15:00Z', 'home_team': 'Sporting Gijón', 'away_team': 'SD Huesca', 'bookmakers': [{'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2024-01-14T15:21:56Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:21:56Z', 'outcomes': [{'name': 'SD Huesca', 'price': 4.2}, {'name': 'Sporting Gijón', 'price': 1.95}, {'name': 'Draw', 'price': 2.85}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-01-14T15:24:46Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:46Z', 'outcomes': [{'name': 'SD Huesca', 'price': 4.3}, {'name': 'Sporting Gijón', 'price': 1.95}, {'name': 'Draw', 'price': 3.0}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2024-01-14T15:23:49Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:23:49Z', 'outcomes': [{'name': 'SD Huesca', 'price': 4.33}, {'name': 'Sporting Gijón', 'price': 1.87}, {'name': 'Draw', 'price': 2.85}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2024-01-14T15:23:01Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:23:01Z', 'outcomes': [{'name': 'SD Huesca', 'price': 4.5}, {'name': 'Sporting Gijón', 'price': 1.95}, {'name': 'Draw', 'price': 3.0}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2024-01-14T15:24:45Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:45Z', 'outcomes': [{'name': 'SD Huesca', 'price': 4.75}, {'name': 'Sporting Gijón', 'price': 1.85}, {'name': 'Draw', 'price': 2.85}]}]}, {'key': 'betus', 'title': 'BetUS', 'last_update': '2024-01-14T15:14:51Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:14:51Z', 'outcomes': [{'name': 'SD Huesca', 'price': 4.6}, {'name': 'Sporting Gijón', 'price': 1.95}, {'name': 'Draw', 'price': 2.9}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2024-01-14T15:23:46Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:23:46Z', 'outcomes': [{'name': 'SD Huesca', 'price': 4.75}, {'name': 'Sporting Gijón', 'price': 1.91}, {'name': 'Draw', 'price': 3.0}]}]}, {'key': 'lowvig', 'title': 'LowVig.ag', 'last_update': '2024-01-14T15:14:53Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:14:53Z', 'outcomes': [{'name': 'SD Huesca', 'price': 4.25}, {'name': 'Sporting Gijón', 'price': 1.89}, {'name': 'Draw', 'price': 3.05}]}]}, {'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2024-01-14T15:15:52Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:15:52Z', 'outcomes': [{'name': 'SD Huesca', 'price': 4.25}, {'name': 'Sporting Gijón', 'price': 1.89}, {'name': 'Draw', 'price': 3.05}]}]}]}
#
# {'id': 'db4a2ff9c6063fd90e6fc2a47d5a8b6b', 'sport_key': 'soccer_italy_serie_b', 'sport_title': 'Serie B - Italy', 'commence_time': '2024-01-14T15:15:00Z', 'home_team': 'Venezia', 'away_team': 'Sampdoria', 'bookmakers': [{'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2024-01-14T15:23:45Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:23:45Z', 'outcomes': [{'name': 'Sampdoria', 'price': 4.5}, {'name': 'Venezia', 'price': 1.87}, {'name': 'Draw', 'price': 3.2}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-01-14T15:24:42Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:42Z', 'outcomes': [{'name': 'Sampdoria', 'price': 4.2}, {'name': 'Venezia', 'price': 1.87}, {'name': 'Draw', 'price': 3.35}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2024-01-14T15:24:42Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:42Z', 'outcomes': [{'name': 'Sampdoria', 'price': 4.4}, {'name': 'Venezia', 'price': 1.91}, {'name': 'Draw', 'price': 3.25}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2024-01-14T15:24:43Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:43Z', 'outcomes': [{'name': 'Sampdoria', 'price': 4.0}, {'name': 'Venezia', 'price': 1.83}, {'name': 'Draw', 'price': 3.1}]}]}, {'key': 'betus', 'title': 'BetUS', 'last_update': '2024-01-14T15:15:48Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:15:48Z', 'outcomes': [{'name': 'Sampdoria', 'price': 4.29}, {'name': 'Venezia', 'price': 1.84}, {'name': 'Draw', 'price': 3.3}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2024-01-14T15:24:42Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:42Z', 'outcomes': [{'name': 'Sampdoria', 'price': 4.1}, {'name': 'Venezia', 'price': 1.88}, {'name': 'Draw', 'price': 3.1}]}]}, {'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2024-01-14T15:14:48Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:14:48Z', 'outcomes': [{'name': 'Sampdoria', 'price': 3.85}, {'name': 'Venezia', 'price': 1.88}, {'name': 'Draw', 'price': 3.35}]}]}, {'key': 'lowvig', 'title': 'LowVig.ag', 'last_update': '2024-01-14T15:14:51Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:14:51Z', 'outcomes': [{'name': 'Sampdoria', 'price': 3.85}, {'name': 'Venezia', 'price': 1.88}, {'name': 'Draw', 'price': 3.35}]}]}]}
#
# {'id': 'ed85fef82b31d726969744763cb037b3', 'sport_key': 'soccer_greece_super_league', 'sport_title': 'Super League - Greece', 'commence_time': '2024-01-14T15:30:00Z', 'home_team': 'Asteras Tripolis', 'away_team': 'Volos FC', 'bookmakers': [{'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2024-01-14T15:23:57Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:23:57Z', 'outcomes': [{'name': 'Asteras Tripolis', 'price': 2.3}, {'name': 'Volos FC', 'price': 3.6}, {'name': 'Draw', 'price': 2.9}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-01-14T15:24:55Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:55Z', 'outcomes': [{'name': 'Asteras Tripolis', 'price': 2.25}, {'name': 'Volos FC', 'price': 3.5}, {'name': 'Draw', 'price': 2.85}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2024-01-14T15:23:57Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:23:57Z', 'outcomes': [{'name': 'Asteras Tripolis', 'price': 2.3}, {'name': 'Volos FC', 'price': 3.6}, {'name': 'Draw', 'price': 2.95}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2024-01-14T15:24:55Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:55Z', 'outcomes': [{'name': 'Asteras Tripolis', 'price': 2.25}, {'name': 'Volos FC', 'price': 3.4}, {'name': 'Draw', 'price': 3.0}]}]}, {'key': 'betus', 'title': 'BetUS', 'last_update': '2024-01-14T15:23:57Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:23:57Z', 'outcomes': [{'name': 'Asteras Tripolis', 'price': 2.25}, {'name': 'Volos FC', 'price': 3.5}, {'name': 'Draw', 'price': 2.85}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2024-01-14T15:23:57Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:23:57Z', 'outcomes': [{'name': 'Asteras Tripolis', 'price': 2.23}, {'name': 'Volos FC', 'price': 3.4}, {'name': 'Draw', 'price': 3.0}]}]}]}
#
# {'id': '830fdf289d52b31bb341b35b2674edc2', 'sport_key': 'soccer_portugal_primeira_liga', 'sport_title': 'Primeira Liga - Portugal', 'commence_time': '2024-01-14T15:30:00Z', 'home_team': 'Gil Vicente', 'away_team': 'CF Estrela', 'bookmakers': [{'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2024-01-14T15:25:06Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:06Z', 'outcomes': [{'name': 'CF Estrela', 'price': 3.5}, {'name': 'Gil Vicente', 'price': 2.05}, {'name': 'Draw', 'price': 3.4}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2024-01-14T15:25:05Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:05Z', 'outcomes': [{'name': 'CF Estrela', 'price': 3.45}, {'name': 'Gil Vicente', 'price': 2.1}, {'name': 'Draw', 'price': 3.4}]}]}, {'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2024-01-14T15:24:09Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:09Z', 'outcomes': [{'name': 'CF Estrela', 'price': 3.7}, {'name': 'Gil Vicente', 'price': 1.95}, {'name': 'Draw', 'price': 3.2}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2024-01-14T15:16:13Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:16:13Z', 'outcomes': [{'name': 'CF Estrela', 'price': 3.5}, {'name': 'Gil Vicente', 'price': 2.06}, {'name': 'Draw', 'price': 3.35}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2024-01-14T15:25:06Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:06Z', 'outcomes': [{'name': 'CF Estrela', 'price': 3.5}, {'name': 'Gil Vicente', 'price': 2.06}, {'name': 'Draw', 'price': 3.35}]}]}, {'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2024-01-14T15:25:05Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:05Z', 'outcomes': [{'name': 'CF Estrela', 'price': 3.5}, {'name': 'Gil Vicente', 'price': 2.05}, {'name': 'Draw', 'price': 3.4}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2024-01-14T15:25:05Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:05Z', 'outcomes': [{'name': 'CF Estrela', 'price': 3.65}, {'name': 'Gil Vicente', 'price': 2.05}, {'name': 'Draw', 'price': 3.35}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-01-14T15:25:05Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:05Z', 'outcomes': [{'name': 'CF Estrela', 'price': 3.5}, {'name': 'Gil Vicente', 'price': 2.1}, {'name': 'Draw', 'price': 3.25}]}]}, {'key': 'betus', 'title': 'BetUS', 'last_update': '2024-01-14T15:25:05Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:05Z', 'outcomes': [{'name': 'CF Estrela', 'price': 3.5}, {'name': 'Gil Vicente', 'price': 2.1}, {'name': 'Draw', 'price': 3.25}]}]}, {'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2024-01-14T15:25:05Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:05Z', 'outcomes': [{'name': 'CF Estrela', 'price': 3.52}, {'name': 'Gil Vicente', 'price': 2.12}, {'name': 'Draw', 'price': 3.4}]}]}, {'key': 'lowvig', 'title': 'LowVig.ag', 'last_update': '2024-01-14T15:25:08Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:08Z', 'outcomes': [{'name': 'CF Estrela', 'price': 3.52}, {'name': 'Gil Vicente', 'price': 2.12}, {'name': 'Draw', 'price': 3.4}]}]}]}
#
# ...
#
# {'id': '57d7a850136882009d5ff31e39d1b20a', 'sport_key': 'soccer_france_ligue_one', 'sport_title': 'Ligue 1 - France', 'commence_time': '2024-01-14T16:05:00Z', 'home_team': 'Le Havre', 'away_team': 'Lyon', 'bookmakers': [{'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2024-01-14T15:24:25Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:25Z', 'outcomes': [{'name': 'Le Havre', 'price': 3.1}, {'name': 'Lyon', 'price': 2.4}, {'name': 'Draw', 'price': 3.1}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-01-14T15:25:13Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:13Z', 'outcomes': [{'name': 'Le Havre', 'price': 3.0}, {'name': 'Lyon', 'price': 2.4}, {'name': 'Draw', 'price': 3.25}]}]}, {'key': 'williamhill_us', 'title': 'Caesars', 'last_update': '2024-01-14T15:25:13Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:13Z', 'outcomes': [{'name': 'Le Havre', 'price': 3.1}, {'name': 'Lyon', 'price': 2.35}, {'name': 'Draw', 'price': 3.2}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2024-01-14T15:25:13Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:13Z', 'outcomes': [{'name': 'Le Havre', 'price': 3.1}, {'name': 'Lyon', 'price': 2.45}, {'name': 'Draw', 'price': 3.15}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2024-01-14T15:22:48Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:22:48Z', 'outcomes': [{'name': 'Le Havre', 'price': 3.0}, {'name': 'Lyon', 'price': 2.4}, {'name': 'Draw', 'price': 3.2}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2024-01-14T15:25:14Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:14Z', 'outcomes': [{'name': 'Le Havre', 'price': 3.15}, {'name': 'Lyon', 'price': 2.35}, {'name': 'Draw', 'price': 3.25}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2024-01-14T15:25:14Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:14Z', 'outcomes': [{'name': 'Le Havre', 'price': 3.15}, {'name': 'Lyon', 'price': 2.35}, {'name': 'Draw', 'price': 3.25}]}]}, {'key': 'wynnbet', 'title': 'WynnBET', 'last_update': '2024-01-14T15:25:13Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:13Z', 'outcomes': [{'name': 'Le Havre', 'price': 3.22}, {'name': 'Lyon', 'price': 2.45}, {'name': 'Draw', 'price': 3.22}]}]}, {'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2024-01-14T15:25:13Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:13Z', 'outcomes': [{'name': 'Le Havre', 'price': 3.17}, {'name': 'Lyon', 'price': 2.45}, {'name': 'Draw', 'price': 3.21}]}]}, {'key': 'lowvig', 'title': 'LowVig.ag', 'last_update': '2024-01-14T15:25:15Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:15Z', 'outcomes': [{'name': 'Le Havre', 'price': 3.17}, {'name': 'Lyon', 'price': 2.45}, {'name': 'Draw', 'price': 3.21}]}]}, {'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2024-01-14T15:24:24Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:24Z', 'outcomes': [{'name': 'Le Havre', 'price': 3.1}, {'name': 'Lyon', 'price': 2.4}, {'name': 'Draw', 'price': 3.2}]}]}, {'key': 'betus', 'title': 'BetUS', 'last_update': '2024-01-14T15:24:25Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:25Z', 'outcomes': [{'name': 'Le Havre', 'price': 3.05}, {'name': 'Lyon', 'price': 2.4}, {'name': 'Draw', 'price': 3.25}]}]}, {'key': 'superbook', 'title': 'SuperBook', 'last_update': '2024-01-14T15:21:48Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:21:48Z', 'outcomes': [{'name': 'Le Havre', 'price': 3.0}, {'name': 'Lyon', 'price': 2.4}, {'name': 'Draw', 'price': 3.2}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2024-01-14T15:25:13Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:13Z', 'outcomes': [{'name': 'Le Havre', 'price': 3.0}, {'name': 'Lyon', 'price': 2.45}, {'name': 'Draw', 'price': 3.2}]}]}]}
#
# {'id': '3051b68375728133cd7cdf63b1bfbddd', 'sport_key': 'soccer_germany_bundesliga', 'sport_title': 'Bundesliga - Germany', 'commence_time': '2024-01-14T16:30:00Z', 'home_team': 'Borussia Monchengladbach', 'away_team': 'VfB Stuttgart', 'bookmakers': [{'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2024-01-14T15:24:06Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:06Z', 'outcomes': [{'name': 'Borussia Monchengladbach', 'price': 3.8}, {'name': 'VfB Stuttgart', 'price': 1.83}, {'name': 'Draw', 'price': 3.9}]}]}, {'key': 'williamhill_us', 'title': 'Caesars', 'last_update': '2024-01-14T15:24:05Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:05Z', 'outcomes': [{'name': 'Borussia Monchengladbach', 'price': 3.6}, {'name': 'VfB Stuttgart', 'price': 1.91}, {'name': 'Draw', 'price': 3.8}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2024-01-14T15:25:01Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:01Z', 'outcomes': [{'name': 'Borussia Monchengladbach', 'price': 3.75}, {'name': 'VfB Stuttgart', 'price': 1.83}, {'name': 'Draw', 'price': 3.8}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-01-14T15:25:01Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:01Z', 'outcomes': [{'name': 'Borussia Monchengladbach', 'price': 3.75}, {'name': 'VfB Stuttgart', 'price': 1.91}, {'name': 'Draw', 'price': 3.85}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2024-01-14T15:25:03Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:03Z', 'outcomes': [{'name': 'Borussia Monchengladbach', 'price': 3.8}, {'name': 'VfB Stuttgart', 'price': 1.87}, {'name': 'Draw', 'price': 3.8}]}]}, {'key': 'lowvig', 'title': 'LowVig.ag', 'last_update': '2024-01-14T15:25:03Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:03Z', 'outcomes': [{'name': 'Borussia Monchengladbach', 'price': 3.88}, {'name': 'VfB Stuttgart', 'price': 1.89}, {'name': 'Draw', 'price': 4.07}]}]}, {'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2024-01-14T15:25:01Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:01Z', 'outcomes': [{'name': 'Borussia Monchengladbach', 'price': 3.88}, {'name': 'VfB Stuttgart', 'price': 1.88}, {'name': 'Draw', 'price': 4.07}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2024-01-14T15:25:02Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:02Z', 'outcomes': [{'name': 'Borussia Monchengladbach', 'price': 3.85}, {'name': 'VfB Stuttgart', 'price': 1.85}, {'name': 'Draw', 'price': 3.9}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2024-01-14T15:25:02Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:02Z', 'outcomes': [{'name': 'Borussia Monchengladbach', 'price': 3.85}, {'name': 'VfB Stuttgart', 'price': 1.85}, {'name': 'Draw', 'price': 3.9}]}]}, {'key': 'wynnbet', 'title': 'WynnBET', 'last_update': '2024-01-14T15:25:02Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:02Z', 'outcomes': [{'name': 'Borussia Monchengladbach', 'price': 3.8}, {'name': 'VfB Stuttgart', 'price': 1.9}, {'name': 'Draw', 'price': 4.15}]}]}, {'key': 'betus', 'title': 'BetUS', 'last_update': '2024-01-14T15:25:02Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:02Z', 'outcomes': [{'name': 'Borussia Monchengladbach', 'price': 3.82}, {'name': 'VfB Stuttgart', 'price': 1.88}, {'name': 'Draw', 'price': 3.96}]}]}, {'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2024-01-14T15:25:01Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:01Z', 'outcomes': [{'name': 'Borussia Monchengladbach', 'price': 3.8}, {'name': 'VfB Stuttgart', 'price': 1.91}, {'name': 'Draw', 'price': 3.8}]}]}, {'key': 'superbook', 'title': 'SuperBook', 'last_update': '2024-01-14T15:25:03Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:03Z', 'outcomes': [{'name': 'Borussia Monchengladbach', 'price': 3.75}, {'name': 'VfB Stuttgart', 'price': 1.87}, {'name' ...
#
# {'id': '8e3588a175ef971d5d784210b2fec6be', 'sport_key': 'soccer_epl', 'sport_title': 'EPL', 'commence_time': '2024-01-14T16:30:00Z', 'home_team': 'Manchester United', 'away_team': 'Tottenham Hotspur', 'bookmakers': [{'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2024-01-14T15:24:03Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:03Z', 'outcomes': [{'name': 'Manchester United', 'price': 2.05}, {'name': 'Tottenham Hotspur', 'price': 3.2}, {'name': 'Draw', 'price': 4.0}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2024-01-14T15:25:00Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:00Z', 'outcomes': [{'name': 'Manchester United', 'price': 2.05}, {'name': 'Tottenham Hotspur', 'price': 3.1}, {'name': 'Draw', 'price': 3.9}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-01-14T15:24:59Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:59Z', 'outcomes': [{'name': 'Manchester United', 'price': 2.05}, {'name': 'Tottenham Hotspur', 'price': 3.15}, {'name': 'Draw', 'price': 4.1}]}]}, {'key': 'williamhill_us', 'title': 'Caesars', 'last_update': '2024-01-14T15:24:02Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:02Z', 'outcomes': [{'name': 'Manchester United', 'price': 2.05}, {'name': 'Tottenham Hotspur', 'price': 3.1}, {'name': 'Draw', 'price': 4.0}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2024-01-14T15:24:59Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:59Z', 'outcomes': [{'name': 'Manchester United', 'price': 2.05}, {'name': 'Tottenham Hotspur', 'price': 3.3}, {'name': 'Draw', 'price': 4.0}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2024-01-14T15:24:59Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:59Z', 'outcomes': [{'name': 'Manchester United', 'price': 2.02}, {'name': 'Tottenham Hotspur', 'price': 3.4}, {'name': 'Draw', 'price': 3.95}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2024-01-14T15:25:00Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:25:00Z', 'outcomes': [{'name': 'Manchester United', 'price': 2.02}, {'name': 'Tottenham Hotspur', 'price': 3.4}, {'name': 'Draw', 'price': 3.95}]}]}, {'key': 'wynnbet', 'title': 'WynnBET', 'last_update': '2024-01-14T15:24:59Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:59Z', 'outcomes': [{'name': 'Manchester United', 'price': 2.02}, {'name': 'Tottenham Hotspur', 'price': 3.3}, {'name': 'Draw', 'price': 4.0}]}]}, {'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2024-01-14T15:24:58Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:58Z', 'outcomes': [{'name': 'Manchester United', 'price': 2.05}, {'name': 'Tottenham Hotspur', 'price': 3.2}, {'name': 'Draw', 'price': 4.0}]}]}, {'key': 'betus', 'title': 'BetUS', 'last_update': '2024-01-14T15:24:59Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:59Z', 'outcomes': [{'name': 'Manchester United', 'price': 2.03}, {'name': 'Tottenham Hotspur', 'price': 3.3}, {'name': 'Draw', 'price': 3.95}]}]}, {'key': 'superbook', 'title': 'SuperBook', 'last_update': '2024-01-14T15:24:59Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:59Z', 'outcomes': [{'name': 'Manchester United', 'price': 2.05}, {'name': 'Tottenham Hotspur', 'price': 3.15}, {'name': 'Draw', 'price': 3.95}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2024-01-14T15:24:59Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:59Z', 'outcomes': [{'name': 'Manchester United', 'price': 2.0}, {'name': 'Tottenham Hotspur', 'price': 3.3}, {'name': 'Draw', 'price': 4.0}]}]}]}
#
# {'id': '3f116f92d7a92defd65727204e7892c8', 'sport_key': 'soccer_africa_cup_of_nations', 'sport_title': 'Africa Cup of Nations', 'commence_time': '2024-01-14T17:00:00Z', 'home_team': 'Egypt', 'away_team': 'Mozambique', 'bookmakers': [{'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2024-01-14T15:23:53Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:23:53Z', 'outcomes': [{'name': 'Egypt', 'price': 1.33}, {'name': 'Mozambique', 'price': 10.5}, {'name': 'Draw', 'price': 4.0}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2024-01-14T15:24:50Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:50Z', 'outcomes': [{'name': 'Egypt', 'price': 1.38}, {'name': 'Mozambique', 'price': 10.0}, {'name': 'Draw', 'price': 4.4}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2024-01-14T15:24:50Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:50Z', 'outcomes': [{'name': 'Egypt', 'price': 1.36}, {'name': 'Mozambique', 'price': 8.5}, {'name': 'Draw', 'price': 4.0}]}]}, {'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2024-01-14T15:24:50Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:50Z', 'outcomes': [{'name': 'Egypt', 'price': 1.38}, {'name': 'Mozambique', 'price': 11.0}, {'name': 'Draw', 'price': 4.3}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2024-01-14T15:24:50Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:50Z', 'outcomes': [{'name': 'Egypt', 'price': 1.38}, {'name': 'Mozambique', 'price': 11.0}, {'name': 'Draw', 'price': 4.3}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2024-01-14T15:23:52Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:23:52Z', 'outcomes': [{'name': 'Egypt', 'price': 1.36}, {'name': 'Mozambique', 'price': 9.0}, {'name': 'Draw', 'price': 4.4}]}]}, {'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2024-01-14T15:24:50Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:50Z', 'outcomes': [{'name': 'Egypt', 'price': 1.36}, {'name': 'Mozambique', 'price': 11.0}, {'name': 'Draw', 'price': 4.25}]}]}, {'key': 'williamhill_us', 'title': 'Caesars', 'last_update': '2024-01-14T15:24:50Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:50Z', 'outcomes': [{'name': 'Egypt', 'price': 1.36}, {'name': 'Mozambique', 'price': 11.0}, {'name': 'Draw', 'price': 4.2}]}]}, {'key': 'wynnbet', 'title': 'WynnBET', 'last_update': '2024-01-14T15:24:50Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:50Z', 'outcomes': [{'name': 'Egypt', 'price': 1.4}, {'name': 'Mozambique', 'price': 10.2}, {'name': 'Draw', 'price': 4.4}]}]}, {'key': 'betus', 'title': 'BetUS', 'last_update': '2024-01-14T15:24:50Z', 'markets': [{'key': 'h2h', 'last_update': '2024-01-14T15:24:50Z', 'outcomes': [{'name': 'Egypt', 'price': 1.38}, {'name': 'Mozambique', 'price': 11.0}, {'name': 'Draw', 'price': 4.3}]}]}]}

# %% [markdown]
# ### Creating Dataframe and Writing to Excel File

# %%
MAX_OUTCOMES = max([event.num_outcomes for event in arbitrage_events])
ARBITRAGE_EVENTS_COUNT = len(arbitrage_events)

my_columns = ['ID', 'Sport Key', 'Expected Earnings'] + list(np.array([[f'Bookmaker #{outcome}', f'Name #{outcome}', f'Odds #{outcome}', f'Amount to Buy #{outcome}'] for outcome in range(1, MAX_OUTCOMES + 1)]).flatten())
dataframe = pd.DataFrame(columns=my_columns)

# %%
for event in arbitrage_events:
    # print(event.best_odds)
    row = []
    row.append(event.id)
    row.append(event.sport_key)
    row.append(round(event.expected_earnings, 2))
    for index, outcome in enumerate(event.best_odds):
        row.append(outcome[BOOKMAKER_INDEX])
        row.append(outcome[NAME_INDEX])
        row.append(outcome[ODDS_INDEX])
        row.append(event.bet_amounts[index])
    while len(row) < len(dataframe.columns):
        row.append('N/A')
    dataframe.loc[len(dataframe.index)] = row

# %%
writer = pd.ExcelWriter('bets.xlsx')
dataframe.to_excel(writer, index=False)
writer.save()
# Out:
# <ipython-input-9-b930a8caff5b>:3: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %% [markdown]
# ### Formatting the Excel File

# %%
BLACK = '000000'
LIGHT_GREY = 'D6D6D6'
DARK_GREY = '9F9F9F'
RED = 'FEA0A0'
BLUE = 'A0CEFE'
YELLOW = 'FFE540'

COLORS = [RED, BLUE]

ID_COLUMN_FILL = PatternFill(fill_type='solid', start_color=DARK_GREY, end_color=DARK_GREY)
SPORT_KEY_COLUMN_FILL = PatternFill(fill_type='solid', start_color=LIGHT_GREY, end_color=LIGHT_GREY)
EXPECTED_EARNINGS_COLUMN_FILL = PatternFill(fill_type='solid', start_color=YELLOW, end_color=YELLOW)

CENTER_ALIGNMENT = Alignment(horizontal='center', vertical='bottom', indent=0)

TOP_ROW_BORDER = Border(bottom=Side(border_style='thick', color=BLACK))
NORMAL_ROW_BORDER = Border(top=Side(border_style='thin', color=LIGHT_GREY), bottom=Side(border_style='thin', color=DARK_GREY))

wb = load_workbook('bets.xlsx')
ws = wb.active
ws.title = 'Upcoming'
# changing width
for col in range(1, 26):
    ws.column_dimensions[chr(col + 64)].width = 20

for cell in ws['A']:
    cell.fill = ID_COLUMN_FILL
    cell.alignment = CENTER_ALIGNMENT

for cell in ws['B']:
    cell.fill = SPORT_KEY_COLUMN_FILL
    cell.alignment = CENTER_ALIGNMENT

for cell in ws['C']:
    cell.fill = EXPECTED_EARNINGS_COLUMN_FILL
    cell.alignment = CENTER_ALIGNMENT
    cell.number_format = numbers.BUILTIN_FORMATS[7]

START_INDEX = 'D'
for index in range(MAX_OUTCOMES):
    for col in ws[START_INDEX : chr(ord(START_INDEX) + 3)]:
        for cell in col:
            color = COLORS[int(index % 2)]
            cell.fill = PatternFill(fill_type='solid', start_color=color, end_color=color)
            cell.alignment = CENTER_ALIGNMENT
            if cell.column % 4 == 3:
                cell.number_format = numbers.BUILTIN_FORMATS[7]

    START_INDEX = chr(ord(START_INDEX) + 4)

for cell in ws['1']:
    cell.border = TOP_ROW_BORDER

for row in range(2, ARBITRAGE_EVENTS_COUNT + 2):
    for cell in ws[str(row)]:
        cell.border = NORMAL_ROW_BORDER

wb.save('upcoming_events_bets.xlsx')
